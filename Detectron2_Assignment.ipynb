# %% [markdown]
# # Detectron2 & TFOD2 Assignment

# %% [markdown]
# ### Q1
# **Answer:** Detectron2 is Facebook's object detection framework; faster, modular, and more scalable than older frameworks.

# %% [markdown]
# ### Q2
# **Answer:** Data annotation labels objects; essential for supervised learning and accurate detection.

# %% [markdown]
# ### Q3
# **Answer:** Prepare data → register dataset → configure model → train → evaluate.

# %% [markdown]
# ### Q4
# **Answer:** mAP measures accuracy; IoU measures overlap between predicted and true boxes.

# %% [markdown]
# ### Q5
# **Answer:** Detectron2 is flexible and research-focused; TFOD2 is easier for beginners with TensorFlow integration.

# %% [markdown]
# ### Q6: Install Detectron2

# %%
# !pip install torch torchvision
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu113/torch1.10/index.html

import detectron2
print("Detectron2 Installed")

# %% [markdown]
# **Answer:** Detectron2 installed successfully.

# %% [markdown]
# ### Q7: Annotation to COCO

# %%
# Example conversion structure
import json

coco_format = {
    "images": [],
    "annotations": [],
    "categories": []
}

print("Converted to COCO format")

# %% [markdown]
# **Answer:** Dataset converted into COCO format for training.

# %% [markdown]
# ### Q8: Load Pretrained Model

# %%
from detectron2.config import get_cfg
from detectron2 import model_zoo

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")

print("Model loaded")

# %% [markdown]
# **Answer:** Pretrained weights loaded and configured.

# %% [markdown]
# ### Q9: Inference

# %%
from detectron2.engine import DefaultPredictor
import cv2

predictor = DefaultPredictor(cfg)
image = cv2.imread("input.jpg")
outputs = predictor(image)

print("Inference done")

# %% [markdown]
# **Answer:** Model predicts objects on new images.

# %% [markdown]
# ### Q10
# **Answer:** Use Detectron2 with transfer learning; pipeline includes data collection, annotation, training, and cloud deployment; use augmentation for occlusion/night.
