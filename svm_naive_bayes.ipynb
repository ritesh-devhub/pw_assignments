# %% [markdown]
# # SVM & Naive Bayes Assignment

# %% [markdown]
# ### Q1
# **Answer:** SVM is a supervised model that finds optimal hyperplane for classification.

# %% [markdown]
# ### Q2
# **Answer:** Hard margin has no tolerance; soft margin allows misclassification.

# %% [markdown]
# ### Q3
# **Answer:** SVM maximizes margin between classes.

# %% [markdown]
# ### Q4
# **Answer:** Lagrange multipliers optimize constraints in SVM.

# %% [markdown]
# ### Q5
# **Answer:** Support vectors are closest points to boundary.

# %% [markdown]
# ### Q6
# **Answer:** SVC is classification version of SVM.

# %% [markdown]
# ### Q7
# **Answer:** SVR is regression version of SVM.

# %% [markdown]
# ### Q8
# **Answer:** Kernel trick maps data to higher dimensions.

# %% [markdown]
# ### Q9
# **Answer:** Linear is simple, Polynomial complex, RBF flexible.

# %% [markdown]
# ### Q10
# **Answer:** C controls margin vs error tradeoff.

# %% [markdown]
# ### Q11
# **Answer:** Gamma controls influence of points.

# %% [markdown]
# ### Q12
# **Answer:** Naive Bayes uses Bayes theorem with independence assumption.

# %% [markdown]
# ### Q13
# **Answer:** Bayes theorem calculates conditional probability.

# %% [markdown]
# ### Q14
# **Answer:** Gaussian handles continuous, Multinomial counts, Bernoulli binary.

# %% [markdown]
# ### Q15
# **Answer:** Gaussian NB for continuous data.

# %% [markdown]
# ### Q16
# **Answer:** NB assumes feature independence.

# %% [markdown]
# ### Q17
# **Answer:** NB is fast but less accurate sometimes.

# %% [markdown]
# ### Q18
# **Answer:** NB works well for text due to independence.

# %% [markdown]
# ### Q19
# **Answer:** SVM is powerful; NB is faster and simpler.

# %% [markdown]
# ### Q20
# **Answer:** Laplace smoothing avoids zero probability.

# %% [markdown]
# ## Practical Questions

# %% [markdown]
# ### Q21

# %%
# Q21
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q22

# %%
# Q22
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q23

# %%
# Q23
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q24

# %%
# Q24
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q25

# %%
# Q25
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q26

# %%
# Q26
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q27

# %%
# Q27
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q28

# %%
# Q28
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q29

# %%
# Q29
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q30

# %%
# Q30
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q31

# %%
# Q31
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q32

# %%
# Q32
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q33

# %%
# Q33
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q34

# %%
# Q34
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q35

# %%
# Q35
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q36

# %%
# Q36
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q37

# %%
# Q37
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q38

# %%
# Q38
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q39

# %%
# Q39
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q40

# %%
# Q40
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q41

# %%
# Q41
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q42

# %%
# Q42
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q43

# %%
# Q43
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q44

# %%
# Q44
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q45

# %%
# Q45
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.

# %% [markdown]
# ### Q46

# %%
# Q46
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X,y=datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=SVC()
model.fit(X_train,y_train)
pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# **Answer:** Model trained and evaluated.
